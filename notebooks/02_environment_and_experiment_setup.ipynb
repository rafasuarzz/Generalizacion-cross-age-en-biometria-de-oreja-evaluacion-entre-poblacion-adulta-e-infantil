# %% [markdown]
# # Environment Setup and Experiment Configuration
#
# This notebook mounts external storage (if needed), unpacks the image dataset, imports the required libraries, and defines the main experiment configuration.

# %% [markdown]
# **Comienzo de la estructura base del codigo**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/images.zip -d /content/images

# %%
import os
import random
import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from sklearn.metrics import roc_auc_score, roc_curve
from tqdm import tqdm

# %%
METADATA_CSV = "metadata_unificado_final.csv"
IMAGES_ROOT = "/content/images"   # cambia esto según tu caso
OUTPUT_DIR = "runs/ALL_to_EICZA"
EXPERIMENT_NAME = "ALL_to_EICZA"

TRAIN_DATASETS = ["AMI", "BIPLab", "UERC"]
TEST_DATASETS = ["EICZA"]

TRAIN_AGE_GROUP = "adulto"
TEST_AGE_GROUP = "adulto"

IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 10
LR = 1e-4
NUM_WORKERS = 2
SEED = 42

VAL_RATIO = 0.1

N_GENUINE_PAIRS = 3000
N_IMPOSTOR_PAIRS = 3000
